# %%
import pickle
import pandas as pd
file_path = 'BestTextLayersAlgonauts2.pkl'

# Load the dictionary from the file using Pickle
with open(file_path, 'rb') as file:
    best_text_layers = pickle.load(file)

# %%
import os
import numpy as np
import torch
from scipy.spatial.distance import pdist, squareform
from scipy import stats
import sys
sys.path.append("/Users/sebastian/University/Bachelor/Thesis/ba-thesis/")
from utils import load_files, get_rdms, get_rdm, get_spearmanr, inter_intra_similarity, get_upper_triu
# %load_ext autoreload
# %autoreload 2

# %%
def load_tensors(directory):
    d = {}
    for key in os.listdir(directory):
        if key.endswith(".pt"):
            filename = os.path.join(directory, key)
            tensor = torch.load(filename)
            d[key[:-3]] = tensor
    return d

# %%
def get_spearmanr_between_tensors(tensor1, tensor2, size):
    v1 = get_upper_triu(tensor1, size)
    v2 = get_upper_triu(tensor2, size)
    res = stats.spearmanr(v1, v2)
    return res.correlation

# %%
avg_visual = load_tensors("avg_visual_lhrh/")
avg_words = load_tensors("avg_words_lhrh/")
avg_faces = load_tensors("avg_faces_lhrh/")
avg_streams = load_tensors("avg_streams_lhrh/")
avg_places = load_tensors("avg_places_lhrh/")
avg_body = load_tensors("avg_body_lhrh/")
clip_txt = load_tensors("clip_txt_rdms/")
albef_txt = load_tensors("albef3_txt_rdms/")
albef_multi = load_tensors("albef3_multi_rdms/")
vilt = load_tensors("vilt_rdms/")
gpt = load_tensors("gpt_rdms/")
bert = load_tensors("bert_txt_rdms/")

# %%
avg = avg_visual | avg_words | avg_faces | avg_streams | avg_places | avg_body

# %%
def get_random_indices(size, amount_of_changed_idx):
    rand_arr = np.random.choice(np.arange(0, size-1), replace=False, size=amount_of_changed_idx)
    return rand_arr

# %%
def permutation_test(model1_layer, model2_layer, roi):
    np.random.seed(0)
    l = []
    roi_flat = get_upper_triu(roi, 872)
    model1_layer_flat = get_upper_triu(model1_layer, 872)
    model2_layer_flat = get_upper_triu(model2_layer, 872)
    corr_model1 = stats.spearmanr(model1_layer_flat, roi_flat).correlation
    corr_model2 = stats.spearmanr(model2_layer_flat, roi_flat).correlation
    p_true = corr_model1 - corr_model2
    for i in range(300):
        rand_int = np.random.randint(379756)
        rand_arr = get_random_indices(379756, rand_int)
        model1_layer_flat = get_upper_triu(model1_layer, 872)
        model2_layer_flat = get_upper_triu(model2_layer, 872)
        model1_layer_flat[rand_arr], model2_layer_flat[rand_arr] = model2_layer_flat[rand_arr], model1_layer_flat[rand_arr]
        corr_model1 = stats.spearmanr(model1_layer_flat, roi_flat).correlation
        corr_model2 = stats.spearmanr(model2_layer_flat, roi_flat).correlation
        l.append(corr_model1-corr_model2)
    return p_true, l

# %%
from tqdm import tqdm
def permutation_df(rdm_mods1, rdm_mods2, name_mods1, name_mods2, best_layers_all_regions, avg):
    list_of_rows = sorted(avg.keys())

    df = pd.DataFrame(index=list_of_rows)
    for i in range(len(rdm_mods1)):
        l_diff = []
        l_p = []
        rdm_mod1 = rdm_mods1[i]
        rdm_mod2 = rdm_mods2[i]
        name_mod1 = name_mods1[i]
        name_mod2 = name_mods2[i]
        for k, v in tqdm(sorted(avg.items())):
            avg_roi = avg[k]
            best_layers = best_layers_all_regions[k]
            mod2_layer_name = best_layers[name_mod2][0]
            mod1_layer_name = best_layers[name_mod1][0]
            best_mod2_layer = rdm_mod2[mod2_layer_name]
            best_mod1_layer = rdm_mod1[mod1_layer_name]
            p_true, l1 = permutation_test(best_mod1_layer, best_mod2_layer, avg_roi)
            # filter with broadcasting the amount of values that are GREATER than the true SPEARMAN R
            count_of_greater_values = np.sum(l1 > p_true) / 300
            l_diff.append(count_of_greater_values)
            l_p.append(p_true)
        df[f"{name_mod1}-{name_mod2} difference"] = np.array(l_p)
        df[f"{name_mod1}-{name_mod2} p-value"] = np.array(l_diff)
    return df

# %%
df_res_perm_txt = permutation_df([clip_txt, albef_txt, albef_multi], [gpt, bert, bert], ['Clip', 'Albef Text', 'Albef Multi'], ['Gpt', 'Bert', 'Bert'], best_text_layers, avg)
df_res_perm_txt
# Out:
# 100%|█████████████████████████████████████████████| 27/27 [30:36<00:00, 68.03s/it]
# 100%|█████████████████████████████████████████████| 27/27 [33:28<00:00, 74.38s/it]
# 100%|█████████████████████████████████████████████| 27/27 [29:08<00:00, 64.76s/it]
#              Clip-Gpt difference  Clip-Gpt p-value  \
# EBA                     0.114782          0.003333
# FBA-1                   0.054937          0.006667
# FBA-2                   0.101544          0.003333
# FFA-1                   0.083714          0.006667
# FFA-2                   0.099872          0.003333
# OFA                     0.020085          0.006667
# OPA                     0.024839          0.013333
# OWFA                    0.014180          0.036667
# PPA                     0.047742          0.006667
# RSC                     0.008723          0.043333
# V1d                     0.021129          0.020000
# V1v                     0.013700          0.036667
# V2d                     0.015510          0.020000
# V2v                     0.019509          0.023333
# V3d                     0.020180          0.020000
# V3v                     0.028450          0.016667
# VWFA-1                  0.039915          0.006667
# VWFA-2                  0.022204          0.023333
# early                   0.025601          0.010000
# hV4                     0.020890          0.006667
# lateral                 0.115394          0.003333
# mfs-words               0.031130          0.003333
# midlateral              0.041018          0.006667
# midparietal             0.050497          0.006667
# midventral              0.024758          0.016667
# parietal                0.038587          0.010000
# ventral                 0.066936          0.006667
#
#              Albef Text-Bert difference  Albef Text-Bert p-value  \
# EBA                           -0.061703                 0.996667
# FBA-1                         -0.050926                 1.000000
# FBA-2                         -0.054929                 1.000000
# FFA-1                         -0.049577                 0.996667
# FFA-2                         -0.054179                 0.996667
# OFA                           -0.015654                 0.986667
# OPA                           -0.027765                 0.996667
# OWFA                          -0.006343                 0.963333
# PPA                           -0.026824                 0.990000
# RSC                           -0.016896                 0.993333
# V1d                           -0.002683                 0.866667
# V1v                           -0.003315                 0.913333
# V2d                           -0.008685                 0.980000
# V2v                           -0.005906                 0.950000
# V3d                           -0.011532                 0.986667
# V3v                           -0.009593                 0.966667
# VWFA-1                        -0.035270                 0.996667
# VWFA-2                        -0.007004                 0.960000
# early                         -0.008930                 0.973333
# hV4                           -0.015955                 0.986667
# lateral                       -0.056771                 0.996667
# mfs-words                     -0.012029                 0.963333
# midlateral                    -0.033446                 0.996667
# midparietal                   -0.025898                 0.996667
# midventral                    -0.014653                 0.990000
# parietal                      -0.012389                 0.973333
# ventral                       -0.037182                 1.000000
#
#              Albef Multi-Bert difference  Albef Multi-Bert p-value
# EBA                            -0.010832                  0.976667
# FBA-1                          -0.009668                  0.973333
# FBA-2                          -0.014421                  0.983333
# FFA-1                          -0.016287                  0.990000
# FFA-2                          -0.014053                  0.983333
# OFA                            -0.003338                  0.883333
# OPA                             0.003148                  0.110000
# OWFA                           -0.000237                  0.583333
# PPA                             0.001587                  0.160000
# RSC                             0.001348                  0.216667
# V1d                             0.005332                  0.043333
# V1v                             0.002580                  0.116667
# V2d                             0.001045                  0.296667
# V2v                             0.000964                  0.263333
# V3d                            -0.000506                  0.613333
# V3v                             0.001149                  0.263333
# VWFA-1                         -0.010257                  0.990000
# VWFA-2                          0.009472                  0.016667
# early                           0.005356                  0.040000
# hV4                             0.003051                  0.106667
# lateral                        -0.008804                  0.966667
# mfs-words                       0.004450                  0.050000
# midlateral                     -0.011459                  0.993333
# midparietal                    -0.002634                  0.846667
# midventral                      0.000627                  0.373333
# parietal                        0.008780                  0.033333
# ventral                        -0.000133                  0.526667

# %%
df_res_perm_txt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df_res_perm_txt
#
# NameError: name 'df_res_perm_txt' is not defined

# %%
best_text_layers
# Out:
# {'OFA': {'Albef Text': ('ALBEF Text Layer 6', 0.011354626952903332),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.023671037303942738),
#   'Gpt': ('GPT Text Layer 12', 0.03437040433239407),
#   'Bert': ('Bert Text Layer 4', 0.027009034975266143),
#   'Clip': ('CLIP Text Layer 4', 0.05445578155766811)},
#  'FFA-1': {'Albef Text': ('ALBEF Text Layer 6', 0.03540818060565114),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.0686979322869777),
#   'Gpt': ('GPT Text Layer 12', 0.09901205337515598),
#   'Bert': ('Bert Text Layer 4', 0.08498483134088793),
#   'Clip': ('CLIP Text Layer 11', 0.1827256289947488)},
#  'FFA-2': {'Albef Text': ('ALBEF Text Layer 6', 0.03396416473710426),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.07409001698156488),
#   'Gpt': ('GPT Text Layer 12', 0.10734048736967997),
#   'Bert': ('Bert Text Layer 3', 0.08814305462100133),
#   'Clip': ('CLIP Text Layer 3', 0.20721290099858858)},
#  'PPA': {'Albef Text': ('ALBEF Text Layer 3', 0.1122910168950697),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.10774053367046299),
#   'Gpt': ('GPT Text Layer 6', 0.036853637427702035),
#   'Bert': ('Bert Text Layer 6', 0.07421077905528684),
#   'Clip': ('CLIP Text Layer 11', 0.14693224789006692)},
#  'RSC': {'Albef Text': ('ALBEF Text Layer 3', 0.11704741563602626),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.12750902408290732),
#   'Gpt': ('GPT Text Layer 12', 0.026601473699243393),
#   'Bert': ('Bert Text Layer 6', 0.09495388492239105),
#   'Clip': ('CLIP Text Layer 11', 0.14439979296429806)},
#  'OPA': {'Albef Text': ('ALBEF Text Layer 3', 0.07724056604647302),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.08588432389088141),
#   'Gpt': ('GPT Text Layer 6', 0.031172272680497565),
#   'Bert': ('Bert Text Layer 4', 0.058106163838741356),
#   'Clip': ('CLIP Text Layer 7', 0.11201537150084052)},
#  'EBA': {'Albef Text': ('ALBEF Text Layer 6', 0.03663615952270008),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.08750772572827208),
#   'Gpt': ('GPT Text Layer 12', 0.11489182483653054),
#   'Bert': ('Bert Text Layer 3', 0.09833940854413724),
#   'Clip': ('CLIP Text Layer 3', 0.22967374549688294)},
#  'FBA-1': {'Albef Text': ('ALBEF Text Layer 6', 0.036877065179763885),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.07813416499219965),
#   'Gpt': ('GPT Text Layer 12', 0.1284820634370733),
#   'Bert': ('Bert Text Layer 4', 0.0878026633702881),
#   'Clip': ('CLIP Text Layer 11', 0.18341936281423857)},
#  'FBA-2': {'Albef Text': ('ALBEF Text Layer 6', 0.033637767915484035),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.0741461934536757),
#   'Gpt': ('GPT Text Layer 12', 0.10553257524256401),
#   'Bert': ('Bert Text Layer 3', 0.08856701853936338),
#   'Clip': ('CLIP Text Layer 3', 0.20707620100807772)},
#  'early': {'Albef Text': ('ALBEF Text Layer 5', 0.012771336876147473),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.027057692444262253),
#   'Gpt': ('GPT Text Layer 12', 0.04289493865369571),
#   'Bert': ('Bert Text Layer 6', 0.02170141337089796),
#   'Clip': ('CLIP Text Layer 4', 0.06849553328266769)},
#  'ventral': {'Albef Text': ('ALBEF Text Layer 6', 0.04258264188149667),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.07963103967370626),
#   'Gpt': ('GPT Text Layer 12', 0.12467397908717943),
#   'Bert': ('Bert Text Layer 4', 0.0797642435650196),
#   'Clip': ('CLIP Text Layer 4', 0.19161004224475361)},
#  'midventral': {'Albef Text': ('ALBEF Text Layer 6', 0.010652210325582459),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.025932977413814794),
#   'Gpt': ('GPT Text Layer 12', 0.03689693046897343),
#   'Bert': ('Bert Text Layer 4', 0.0253057015158824),
#   'Clip': ('CLIP Text Layer 4', 0.06165460725937929)},
#  'lateral': {'Albef Text': ('ALBEF Text Layer 6', 0.03667786667488979),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.08464466944900953),
#   'Gpt': ('GPT Text Layer 12', 0.1114533706814886),
#   'Bert': ('Bert Text Layer 3', 0.09344905848245859),
#   'Clip': ('CLIP Text Layer 3', 0.22684779354144713)},
#  'midparietal': {'Albef Text': ('ALBEF Text Layer 6', 0.025424498565844736),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.048687863973691244),
#   'Gpt': ('GPT Text Layer 12', 0.07294162158477456),
#   'Bert': ('Bert Text Layer 4', 0.05132224592428667),
#   'Clip': ('CLIP Text Layer 4', 0.12343869492208563)},
#  'midlateral': {'Albef Text': ('ALBEF Text Layer 6', 0.01701391770178656),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.039000505492149194),
#   'Gpt': ('GPT Text Layer 12', 0.06303369823547798),
#   'Bert': ('Bert Text Layer 4', 0.050459497028777264),
#   'Clip': ('CLIP Text Layer 4', 0.10405137258247678)},
#  'parietal': {'Albef Text': ('ALBEF Text Layer 6', 0.025801467571531116),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.04697069018655139),
#   'Gpt': ('GPT Text Layer 12', 0.06466310357571195),
#   'Bert': ('Bert Text Layer 4', 0.03819061314054769),
#   'Clip': ('CLIP Text Layer 4', 0.10325008690181176)},
#  'V3v': {'Albef Text': ('ALBEF Text Layer 5', 0.007803469944054662),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.018545252424461357),
#   'Gpt': ('GPT Text Layer 12', 0.02425364028235775),
#   'Bert': ('Bert Text Layer 4', 0.017396690107311666),
#   'Clip': ('CLIP Text Layer 4', 0.05270363165441218)},
#  'V2v': {'Albef Text': ('ALBEF Text Layer 5', 0.00754339799849594),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.014413385880921671),
#   'Gpt': ('GPT Text Layer 9', 0.023630283120663672),
#   'Bert': ('Bert Text Layer 9', 0.01344914674376993),
#   'Clip': ('CLIP Text Layer 4', 0.04313954896696413)},
#  'V1v': {'Albef Text': ('ALBEF Text Layer 5', 0.00718113601515199),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.013075850715434585),
#   'Gpt': ('GPT Text Layer 8', 0.02266961689717993),
#   'Bert': ('Bert Text Layer 6', 0.010495671262864001),
#   'Clip': ('CLIP Text Layer 4', 0.03636944741604608)},
#  'V2d': {'Albef Text': ('ALBEF Text Layer 5', 0.008666741816263129),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.018396295526430153),
#   'Gpt': ('GPT Text Layer 12', 0.03364640788389471),
#   'Bert': ('Bert Text Layer 4', 0.01735165022036),
#   'Clip': ('CLIP Text Layer 3', 0.04915622419094169)},
#  'V3d': {'Albef Text': ('ALBEF Text Layer 5', 0.008675775527040023),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.019701428372574985),
#   'Gpt': ('GPT Text Layer 12', 0.03793431199456405),
#   'Bert': ('Bert Text Layer 4', 0.0202075834211256),
#   'Clip': ('CLIP Text Layer 4', 0.058113824696300914)},
#  'V1d': {'Albef Text': ('ALBEF Text Layer 3', 0.005339694720647077),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.013353760584191226),
#   'Gpt': ('GPT Text Layer 9', 0.019484798230508103),
#   'Bert': ('Bert Text Layer 3', 0.008022213594342902),
#   'Clip': ('CLIP Text Layer 3', 0.04061368353549376)},
#  'hV4': {'Albef Text': ('ALBEF Text Layer 5', 0.014984531928603675),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.03399028666027307),
#   'Gpt': ('GPT Text Layer 12', 0.05237776837362501),
#   'Bert': ('Bert Text Layer 4', 0.03093961825697928),
#   'Clip': ('CLIP Text Layer 4', 0.07326758674756284)},
#  'VWFA-1': {'Albef Text': ('ALBEF Text Layer 6', 0.023642769707770652),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.048655615626822774),
#   'Gpt': ('GPT Text Layer 12', 0.08526015601756806),
#   'Bert': ('Bert Text Layer 4', 0.05891303431456764),
#   'Clip': ('CLIP Text Layer 4', 0.1251755048737181)},
#  'OWFA': {'Albef Text': ('ALBEF Text Layer 4', 0.004438214841937566),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.010544183151686697),
#   'Gpt': ('GPT Text Layer 10', 0.01243689922763195),
#   'Bert': ('Bert Text Layer 9', 0.01078162200041421),
#   'Clip': ('CLIP Text Layer 4', 0.026616822420582623)},
#  'mfs-words': {'Albef Text': ('ALBEF Text Layer 6', 0.01898936904956595),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.03546895832159113),
#   'Gpt': ('GPT Text Layer 12', 0.05310746279946784),
#   'Bert': ('Bert Text Layer 3', 0.031018701383031328),
#   'Clip': ('CLIP Text Layer 11', 0.08423702669974155)},
#  'VWFA-2': {'Albef Text': ('ALBEF Text Layer 6', 0.017438024826517313),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.033913847553976),
#   'Gpt': ('GPT Text Layer 8', 0.05125392948040653),
#   'Bert': ('Bert Text Layer 6', 0.024441604334379842),
#   'Clip': ('CLIP Text Layer 4', 0.07345807666558947)},
#  'PFS': {'Albef Text': ('ALBEF Text Layer 6', 0.12139645667759096),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.1377993640895091),
#   'Gpt': ('GPT Text Layer 12', 0.08487828573061397),
#   'Bert': ('Bert Text Layer 3', 0.10562991735679891),
#   'Clip': ('CLIP Text Layer 11', 0.14219926931933746)},
#  'LOC': {'Albef Text': ('ALBEF Text Layer 6', 0.07580631215449045),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.08240648770856679),
#   'Gpt': ('GPT Text Layer 12', 0.04912534585113049),
#   'Bert': ('Bert Text Layer 11', 0.03297591121480185),
#   'Clip': ('CLIP Text Layer 4', 0.09006287233095096)},
#  'EVC': {'Albef Text': ('ALBEF Text Layer 6', 0.07779340427872727),
#   'Albef Multi': ('ALBEF Multi Layer 5', 0.06968936032508571),
#   'Gpt': ('GPT Text Layer 1', 0.04137530630328651),
#   'Bert': ('Bert Text Layer 7', 0.057407710298538),
#   'Clip': ('CLIP Text Layer 12', 0.09491690997715377)}}
