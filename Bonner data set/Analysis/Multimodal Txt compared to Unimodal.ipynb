# %%
import os
import torch
import sys
sys.path.append("/Users/sebastian/University/Bachelor/Thesis/ba-thesis/")
from utils import load_files, get_rdms, get_rdm, get_spearmanr, inter_intra_similarity
# %load_ext autoreload
# %autoreload 2

# %%
def load_tensors(directory):
    d = {}
    for key in os.listdir(directory):
        if key.endswith(".pt"):
            filename = os.path.join(directory, key)
            tensor = torch.load(filename)
            d[key[:-3]] = tensor
    return d

# %%
avg = load_tensors("avg/")
clip_txt = load_tensors("sclip_txt_rdms/")
albef_txt = load_tensors("salbef_txt_rdms/")
albef_multi = load_tensors("salbef_multi_rdms/")
vilt = load_tensors("svilt_rdms/")
bert = load_tensors("sbert_txt_rdms/")
gpt = load_tensors("sgpt_rdms/")

# %%
avg_evc = {'EVC': avg['EVC']}
avg_rsc = {'RSC': avg['RSC']}
avg_ppa = {'PPA': avg['PPA']}
avg_opa = {'OPA': avg['OPA']}
avg_pfs = {'PFS': avg['PFS']}
avg_loc = {'LOC': avg['LOC']}

# %%
evc_comp = avg_evc | clip_txt | albef_txt | albef_multi | vilt | bert | gpt
rsc_comp = avg_rsc | clip_txt | albef_txt | albef_multi | vilt | bert | gpt
ppa_comp = avg_ppa | clip_txt | albef_txt | albef_multi | vilt | bert | gpt
opa_comp = avg_opa | clip_txt | albef_txt | albef_multi | vilt | bert | gpt
pfs_comp = avg_pfs | clip_txt | albef_txt | albef_multi | vilt | bert | gpt
loc_comp = avg_loc | clip_txt | albef_txt | albef_multi | vilt | bert | gpt

# %%
_, all_res_evc = get_spearmanr(evc_comp, 81)
_, all_res_rsc = get_spearmanr(rsc_comp, 81)
_, all_res_ppa = get_spearmanr(ppa_comp, 81)
_, all_res_opa = get_spearmanr(opa_comp, 81)
_, all_res_pfs = get_spearmanr(pfs_comp, 81)
_, all_res_loc = get_spearmanr(loc_comp, 81)
# Out:
# 100%|███████████████████████████████████████████| 61/61 [00:02<00:00, 30.29it/s]
# 100%|███████████████████████████████████████████| 61/61 [00:01<00:00, 30.92it/s]
# 100%|███████████████████████████████████████████| 61/61 [00:01<00:00, 30.98it/s]
# 100%|███████████████████████████████████████████| 61/61 [00:01<00:00, 30.94it/s]
# 100%|███████████████████████████████████████████| 61/61 [00:01<00:00, 30.85it/s]
# 100%|███████████████████████████████████████████| 61/61 [00:02<00:00, 30.38it/s]

# %%
def filter_results(res, avg):
    filtered = {key: res[key] for key in list(avg.keys()) if key in res}
    return filtered

# %%
f_evc = filter_results(all_res_evc, avg_evc)
f_rsc = filter_results(all_res_rsc, avg_rsc)
f_ppa = filter_results(all_res_ppa, avg_ppa)
f_opa = filter_results(all_res_opa, avg_opa)
f_pfs = filter_results(all_res_pfs, avg_pfs)
f_loc = filter_results(all_res_loc, avg_loc)

# %%
all_filtered = {}
all_filtered['EVC'] = f_evc
all_filtered['RSC'] = f_rsc
all_filtered['PPA'] = f_ppa
all_filtered['OPA'] = f_opa
all_filtered['PFS'] = f_pfs
all_filtered['LOC'] = f_loc

# %%
all_filtered
# Out:
# {'ESC': {'EVC': {'EVC': 1.0,
#    'CLIP Text Layer 9': 0.03838676578082989,
#    'CLIP Text Layer 12': 0.09491690997715377,
#    'CLIP Text Layer 8': 0.031245761089785423,
#    'CLIP Text Layer 3': 0.08146978215720602,
#    'CLIP Text Layer 7': 0.036063035479368684,
#    'CLIP Text Layer 6': 0.039163646425773704,
#    'CLIP Text Layer 2': 0.01799874075614462,
#    'CLIP Text Layer 5': 0.024656655791975405,
#    'CLIP Text Layer 1': 0.015604180148806024,
#    'CLIP Text Layer 4': 0.08903405859229759,
#    'CLIP Text Layer 11': 0.047011419080298836,
#    'CLIP Text Layer 10': 0.03725882531876169,
#    'ALBEF Text Layer 1': 0.026930148503481608,
#    'ALBEF Text Layer 5': 0.07712415071364485,
#    'ALBEF Text Layer 4': 0.060521450525831536,
#    'ALBEF Text Layer 3': 0.027216306354469283,
#    'ALBEF Text Layer 2': 0.04946603857101391,
#    'ALBEF Text Layer 6': 0.07779340427872727,
#    'ALBEF Multi Layer 4': 0.06674603437449875,
#    'ALBEF Multi Layer 1': 0.022362388665149897,
#    'ALBEF Multi Layer 5': 0.06968936032508571,
#    'ALBEF Multi Layer 2': 0.016042069697538915,
#    'ALBEF Multi Layer 6': 0.03132252291073275,
#    'ALBEF Multi Layer 3': 0.061704162948047384,
#    'VILT Layer 6': 0.10408799545848886,
#    'VILT Layer 2': 0.10703017123425258,
#    'VILT Layer 3': 0.09071619421065996,
#    'VILT Layer 7': 0.09743508897535452,
#    'VILT Layer 10': 0.10495978422550965,
#    'VILT Layer 8': 0.09722171566900062,
#    'VILT Layer 9': 0.10120951996314163,
#    'VILT Layer 11': 0.10032995410911828,
#    'VILT Layer 12': 0.09503836279345614,
#    'VILT Layer 4': 0.06584163532872471,
#    'VILT Layer 5': 0.09251899516366659,
#    'VILT Layer 1': 0.043780280932176334,
#    'Bert Text Layer 4': 0.020175875278542088,
#    'Bert Text Layer 5': 0.03626977340599856,
#    'Bert Text Layer 1': 0.008293822799473093,
#    'Bert Text Layer 11': 0.019779891255768744,
#    'Bert Text Layer 10': 0.020686647454301658,
#    'Bert Text Layer 8': 0.05428539174282368,
#    'Bert Text Layer 9': 0.020740518326566336,
#    'Bert Text Layer 12': 0.014360790006821066,
#    'Bert Text Layer 6': 0.050870015698439804,
#    'Bert Text Layer 2': 0.0273537307241681,
#    'Bert Text Layer 3': 0.022940616477405227,
#    'Bert Text Layer 7': 0.057407710298538,
#    'GPT Text Layer 10': 0.039409995879375215,
#    'GPT Text Layer 8': 0.03896057776851852,
#    'GPT Text Layer 11': 0.03614464920343532,
#    'GPT Text Layer 9': 0.04043301887588948,
#    'GPT Text Layer 6': 0.037960871920437345,
#    'GPT Text Layer 2': 0.031299735336658446,
#    'GPT Text Layer 3': 0.03619227138051777,
#    'GPT Text Layer 7': 0.030096142654814407,
#    'GPT Text Layer 4': -0.014685211633913906,
#    'GPT Text Layer 5': 0.031128820063556474,
#    'GPT Text Layer 1': 0.04137530630328651,
#    'GPT Text Layer 12': 0.03760819586071627}},
#  'RSC': {'RSC': {'RSC': 1.0,
#    'CLIP Text Layer 9': 0.10842185242831524,
#    'CLIP Text Layer 12': 0.06529092103893543,
#    'CLIP Text Layer 8': 0.1098474090934367,
#    'CLIP Text Layer 3': 0.05619206830057045,
#    'CLIP Text Layer 7': 0.13423756055851263,
#    'CLIP Text Layer 6': 0.11181086336098449,
#    'CLIP Text Layer 2': -0.0013706912091676076,
#    'CLIP Text Layer 5': 0.03700540793502718,
#    'CLIP Text Layer 1': -0.012894828688040068,
#    'CLIP Text Layer 4': 0.10035184835722559,
#    'CLIP Text Layer 11': 0.14439979296429806,
#    'CLIP Text Layer 10': 0.11196207642161618,
#    'ALBEF Text Layer 1': 0.04215352940688134,
#    'ALBEF Text Layer 5': 0.049821275710195644,
#    'ALBEF Text Layer 4': 0.004115941531363858,
#    'ALBEF Text Layer 3': 0.11704741563602626,
#    'ALBEF Text Layer 2': 0.10354889440627046,
#    'ALBEF Text Layer 6': 0.07013243730339706,
#    'ALBEF Multi Layer 4': 0.06394860457209382,
#    'ALBEF Multi Layer 1': 0.003952643167543642,
#    'ALBEF Multi Layer 5': 0.12750902408290732,
#    'ALBEF Multi Layer 2': 0.02410221401844153,
#    'ALBEF Multi Layer 6': 0.06514721798483353,
#    'ALBEF Multi Layer 3': 0.05863578265214107,
#    'VILT Layer 6': 0.10288776121656575,
#    'VILT Layer 2': 0.12977321166840503,
#    'VILT Layer 3': 0.09634983446461673,
#    'VILT Layer 7': 0.07510117701588152,
#    'VILT Layer 10': 0.10557929414074521,
#    'VILT Layer 8': 0.08750803697888264,
#    'VILT Layer 9': 0.0980996804514449,
#    'VILT Layer 11': 0.11023776219897734,
#    'VILT Layer 12': 0.12086211367987136,
#    'VILT Layer 4': 0.04541937531514482,
#    'VILT Layer 5': 0.08955471062866287,
#    'VILT Layer 1': 0.0720508523478136,
#    'Bert Text Layer 4': 0.048602341954221764,
#    'Bert Text Layer 5': 0.07048206786953715,
#    'Bert Text Layer 1': -0.010605076526617253,
#    'Bert Text Layer 11': 0.04530276628723141,
#    'Bert Text Layer 10': 0.02875099449989575,
#    'Bert Text Layer 8': 0.058302086593889316,
#    'Bert Text Layer 9': 0.018374519453166104,
#    'Bert Text Layer 12': 0.04476040769999989,
#    'Bert Text Layer 6': 0.09495388492239105,
#    'Bert Text Layer 2': 0.032537937343436206,
#    'Bert Text Layer 3': 0.05902036442033255,
#    'Bert Text Layer 7': 0.05888721439664089,
#    'GPT Text Layer 10': 0.020258120540318406,
#    'GPT Text Layer 8': 0.022294596090937525,
#    'GPT Text Layer 11': 0.024092079425865755,
#    'GPT Text Layer 9': 0.022466702465328822,
#    'GPT Text Layer 6': 0.018097836079081126,
#    'GPT Text Layer 2': -0.01593011993610264,
#    'GPT Text Layer 3': 0.02617424055552908,
#    'GPT Text Layer 7': 0.024180057568225666,
#    'GPT Text Layer 4': -0.0030553822619608334,
#    'GPT Text Layer 5': -0.001390382837207011,
#    'GPT Text Layer 1': -0.0012947158114353016,
#    'GPT Text Layer 12': 0.026601473699243393}},
#  'PPA': {'PPA': {'PPA': 1.0,
#    'CLIP Text Layer 9': 0.1162410665242313,
#    'CLIP Text Layer 12': 0.08207989944847106,
#    'CLIP Text Layer 8': 0.11299351615757303,
#    'CLIP Text Layer 3': 0.06470732692021962,
#    'CLIP Text Layer 7': 0.14512428244041542,
#    'CLIP Text Layer 6': 0.1188940869381797,
#    'CLIP Text Layer 2': 0.007220218218999942,
#    'CLIP Text Layer 5': 0.03994876987267914,
#    'CLIP Text Layer 1': -0.004486435069228335,
#    'CLIP Text Layer 4': 0.12018955706672299,
#    'CLIP Text Layer 11': 0.14693224789006692,
#    'CLIP Text Layer 10': 0.1162630644997613,
#    'ALBEF Text Layer 1': 0.03407049025633809,
#    'ALBEF Text Layer 5': 0.058987303950452194,
#    'ALBEF Text Layer 4': 0.018653758261681943,
#    'ALBEF Text Layer 3': 0.1122910168950697,
#    'ALBEF Text Layer 2': 0.08712686445588037,
#    'ALBEF Text Layer 6': 0.08901146718300909,
#    'ALBEF Multi Layer 4': 0.08246737147192384,
#    'ALBEF Multi Layer 1': 0.009342147525212055,
#    'ALBEF Multi Layer 5': 0.10774053367046299,
#    'ALBEF Multi Layer 2': 0.0191750534786309,
#    'ALBEF Multi Layer 6': 0.06370853521415284,
#    'ALBEF Multi Layer 3': 0.07530897656092951,
#    'VILT Layer 6': 0.09229532708701611,
#    'VILT Layer 2': 0.1180560550965917,
#    'VILT Layer 3': 0.08932620088050965,
#    'VILT Layer 7': 0.06610139490344764,
#    'VILT Layer 10': 0.08966355103711848,
#    'VILT Layer 8': 0.0725471206779266,
#    'VILT Layer 9': 0.08436699491774086,
#    'VILT Layer 11': 0.09703571475936759,
#    'VILT Layer 12': 0.10660731404708194,
#    'VILT Layer 4': 0.043282983442566605,
#    'VILT Layer 5': 0.07926218599552569,
#    'VILT Layer 1': 0.0638115915839422,
#    'Bert Text Layer 4': 0.06587374355263946,
#    'Bert Text Layer 5': 0.05973657581305197,
#    'Bert Text Layer 1': -0.007489069467041765,
#    'Bert Text Layer 11': 0.044422260888559516,
#    'Bert Text Layer 10': 0.025350092664751953,
#    'Bert Text Layer 8': 0.039143512721337516,
#    'Bert Text Layer 9': 0.005828220903268064,
#    'Bert Text Layer 12': 0.04150852089200659,
#    'Bert Text Layer 6': 0.07421077905528684,
#    'Bert Text Layer 2': 0.023352075643766346,
#    'Bert Text Layer 3': 0.05275262573004657,
#    'Bert Text Layer 7': 0.041490736225598936,
#    'GPT Text Layer 10': 0.018269467918154255,
#    'GPT Text Layer 8': 0.0203262433487745,
#    'GPT Text Layer 11': 0.024749886281756575,
#    'GPT Text Layer 9': 0.021031861843060672,
#    'GPT Text Layer 6': 0.036853637427702035,
#    'GPT Text Layer 2': -0.008325690756806673,
#    'GPT Text Layer 3': 0.025112759735010027,
#    'GPT Text Layer 7': 0.02277092793984323,
#    'GPT Text Layer 4': 0.006257821784172144,
#    'GPT Text Layer 5': 0.006722550627123473,
#    'GPT Text Layer 1': 0.005084776122686792,
#    'GPT Text Layer 12': 0.02602122179098781}},
#  'OPA': {'OPA': {'OPA': 1.0,
#    'CLIP Text Layer 9': 0.07903628813210137,
#    'CLIP Text Layer 12': 0.08959610774912541,
#    'CLIP Text Layer 8': 0.0773953901621095,
#    'CLIP Text Layer 3': 0.06426287184900656,
#    'CLIP Text Layer 7': 0.11201537150084052,
#    'CLIP Text Layer 6': 0.09394487183141523,
#    'CLIP Text Layer 2': 0.008943360392325057,
#    'CLIP Text Layer 5': 0.0345820372124387,
#    'CLIP Text Layer 1': 0.004354537536525152,
#    'CLIP Text Layer 4': 0.11200580917316146,
#    'CLIP Text Layer 11': 0.1101720614611229,
#    'CLIP Text Layer 10': 0.07952981932838661,
#    'ALBEF Text Layer 1': 0.01329031206723239,
#    'ALBEF Text Layer 5': 0.04136075024111422,
#    'ALBEF Text Layer 4': 0.009799662020069754,
#    'ALBEF Text Layer 3': 0.07724056604647302,
#    'ALBEF Text Layer 2': 0.05263848216890146,
#    'ALBEF Text Layer 6': 0.06589467320627847,
#    'ALBEF Multi Layer 4': 0.06319449879990724,
#    'ALBEF Multi Layer 1': 0.013190045047796523,
#    'ALBEF Multi Layer 5': 0.08588432389088141,
#    'ALBEF Multi Layer 2': 0.019691509493777612,
#    'ALBEF Multi Layer 6': 0.043527126747956585,
#    'ALBEF Multi Layer 3': 0.05315563675648683,
#    'VILT Layer 6': 0.09401850277770572,
#    'VILT Layer 2': 0.11299644486959987,
#    'VILT Layer 3': 0.08673086208676015,
#    'VILT Layer 7': 0.07107808246508629,
#    'VILT Layer 10': 0.09221309699625742,
#    'VILT Layer 8': 0.0760690321945329,
#    'VILT Layer 9': 0.08455277849372633,
#    'VILT Layer 11': 0.09532206117551968,
#    'VILT Layer 12': 0.099436443973028,
#    'VILT Layer 4': 0.05608747683548788,
#    'VILT Layer 5': 0.07963116490133001,
#    'VILT Layer 1': 0.032134435199402726,
#    'Bert Text Layer 4': 0.058106163838741356,
#    'Bert Text Layer 5': 0.03957750261291672,
#    'Bert Text Layer 1': 0.0012622618294448587,
#    'Bert Text Layer 11': 0.051626366075603475,
#    'Bert Text Layer 10': 0.025940513388576513,
#    'Bert Text Layer 8': 0.033668937058845556,
#    'Bert Text Layer 9': 0.019796138709997014,
#    'Bert Text Layer 12': 0.0441244654558099,
#    'Bert Text Layer 6': 0.05273081827427254,
#    'Bert Text Layer 2': 0.021229102007039896,
#    'Bert Text Layer 3': 0.04825162895361614,
#    'Bert Text Layer 7': 0.03662086921018797,
#    'GPT Text Layer 10': 0.01599585101599229,
#    'GPT Text Layer 8': 0.020895655035728402,
#    'GPT Text Layer 11': 0.020214949822053314,
#    'GPT Text Layer 9': 0.01925415410599023,
#    'GPT Text Layer 6': 0.031172272680497565,
#    'GPT Text Layer 2': 0.0014221400108306247,
#    'GPT Text Layer 3': 0.02181164756146902,
#    'GPT Text Layer 7': 0.017877522208579244,
#    'GPT Text Layer 4': 0.0051240976362520825,
#    'GPT Text Layer 5': 0.010626293723962059,
#    'GPT Text Layer 1': 0.015534895875467086,
#    'GPT Text Layer 12': 0.02306136295935297}},
#  'PFS': {'PFS': {'PFS': 1.0,
#    'CLIP Text Layer 9': 0.10029908673331804,
#    'CLIP Text Layer 12': 0.10366346240309421,
#    'CLIP Text Layer 8': 0.09438788918409925,
#    'CLIP Text Layer 3': 0.1225684675345498,
#    'CLIP Text Layer 7': 0.11610346116076427,
#    'CLIP Text Layer 6': 0.11196972367293315,
#    'CLIP Text Layer 2': -0.0027291743357483723,
#    'CLIP Text Layer 5': 0.008736703965813022,
#    'CLIP Text Layer 1': -0.009202423158681158,
#    'CLIP Text Layer 4': 0.11067831161519252,
#    'CLIP Text Layer 11': 0.14219926931933746,
#    'CLIP Text Layer 10': 0.09900621508255787,
#    'ALBEF Text Layer 1': 0.04204144839850205,
#    'ALBEF Text Layer 5': 0.10195350878347058,
#    'ALBEF Text Layer 4': 0.08586867339855524,
#    'ALBEF Text Layer 3': 0.06621664136229134,
#    'ALBEF Text Layer 2': 0.08017722415841454,
#    'ALBEF Text Layer 6': 0.12139645667759096,
#    'ALBEF Multi Layer 4': 0.1012467171814276,
#    'ALBEF Multi Layer 1': 0.04245201670859672,
#    'ALBEF Multi Layer 5': 0.1377993640895091,
#    'ALBEF Multi Layer 2': 0.04712058937018378,
#    'ALBEF Multi Layer 6': 0.07728262716356661,
#    'ALBEF Multi Layer 3': 0.10117414467822596,
#    'VILT Layer 6': 0.12477161823525693,
#    'VILT Layer 2': 0.1261374568356765,
#    'VILT Layer 3': 0.11930622915314748,
#    'VILT Layer 7': 0.11754182004785978,
#    'VILT Layer 10': 0.1370687130633572,
#    'VILT Layer 8': 0.12786864282366256,
#    'VILT Layer 9': 0.134081166418961,
#    'VILT Layer 11': 0.13488982611201894,
#    'VILT Layer 12': 0.13235260395857787,
#    'VILT Layer 4': 0.08342789940188546,
#    'VILT Layer 5': 0.12820249905963504,
#    'VILT Layer 1': 0.06218497377529076,
#    'Bert Text Layer 4': 0.06470358426545743,
#    'Bert Text Layer 5': 0.03163049562659607,
#    'Bert Text Layer 1': 0.017531760251928933,
#    'Bert Text Layer 11': 0.10316284669440091,
#    'Bert Text Layer 10': 0.08334259100581,
#    'Bert Text Layer 8': 0.08371020875380206,
#    'Bert Text Layer 9': 0.07762611029224661,
#    'Bert Text Layer 12': 0.10300812171960043,
#    'Bert Text Layer 6': 0.07843703575914342,
#    'Bert Text Layer 2': 0.03408574912472137,
#    'Bert Text Layer 3': 0.10562991735679891,
#    'Bert Text Layer 7': 0.08188704582546642,
#    'GPT Text Layer 10': 0.08054029165956761,
#    'GPT Text Layer 8': 0.07135928045175961,
#    'GPT Text Layer 11': 0.08236890486418212,
#    'GPT Text Layer 9': 0.0811365412294825,
#    'GPT Text Layer 6': 0.05692845467700652,
#    'GPT Text Layer 2': 0.023812565774961176,
#    'GPT Text Layer 3': 0.07960580636899289,
#    'GPT Text Layer 7': 0.06582492251235171,
#    'GPT Text Layer 4': 0.038913948058239056,
#    'GPT Text Layer 5': 0.03487206155602996,
#    'GPT Text Layer 1': 0.008732121612867011,
#    'GPT Text Layer 12': 0.08487828573061397}},
#  'LOC': {'LOC': {'LOC': 1.0,
#    'CLIP Text Layer 9': 0.04101403744975575,
#    'CLIP Text Layer 12': 0.06553591674382629,
#    'CLIP Text Layer 8': 0.0440050497896392,
#    'CLIP Text Layer 3': 0.077832774833489,
#    'CLIP Text Layer 7': 0.05088951821798066,
#    'CLIP Text Layer 6': 0.05631475032211335,
#    'CLIP Text Layer 2': 0.0019663632219703376,
#    'CLIP Text Layer 5': 0.01667742697551514,
#    'CLIP Text Layer 1': 0.0014926386712068374,
#    'CLIP Text Layer 4': 0.09006287233095096,
#    'CLIP Text Layer 11': 0.06508746287462354,
#    'CLIP Text Layer 10': 0.04675453670670578,
#    'ALBEF Text Layer 1': 0.01945471531156791,
#    'ALBEF Text Layer 5': 0.056308565133516446,
#    'ALBEF Text Layer 4': 0.06185769576311548,
#    'ALBEF Text Layer 3': 0.02970893806464874,
#    'ALBEF Text Layer 2': 0.04220685588658399,
#    'ALBEF Text Layer 6': 0.07580631215449045,
#    'ALBEF Multi Layer 4': 0.06805614206533218,
#    'ALBEF Multi Layer 1': 0.02831604742294987,
#    'ALBEF Multi Layer 5': 0.08240648770856679,
#    'ALBEF Multi Layer 2': 0.03721809148930151,
#    'ALBEF Multi Layer 6': 0.046565350589004004,
#    'ALBEF Multi Layer 3': 0.06243982464378195,
#    'VILT Layer 6': 0.048754210543939795,
#    'VILT Layer 2': 0.04648317730135773,
#    'VILT Layer 3': 0.0764620275268377,
#    'VILT Layer 7': 0.049854775433957874,
#    'VILT Layer 10': 0.06740488132713156,
#    'VILT Layer 8': 0.056005308487242694,
#    'VILT Layer 9': 0.057701612424792464,
#    'VILT Layer 11': 0.07162151854738227,
#    'VILT Layer 12': 0.07693149643075527,
#    'VILT Layer 4': 0.06011175260877027,
#    'VILT Layer 5': 0.051691170664976006,
#    'VILT Layer 1': 0.049256091797753,
#    'Bert Text Layer 4': 0.016764008325812128,
#    'Bert Text Layer 5': 0.013621791392841708,
#    'Bert Text Layer 1': 0.014104979836077015,
#    'Bert Text Layer 11': 0.03297591121480185,
#    'Bert Text Layer 10': 0.029524036171756286,
#    'Bert Text Layer 8': 0.02731532864483266,
#    'Bert Text Layer 9': 0.019263990217614945,
#    'Bert Text Layer 12': 0.02881227906036913,
#    'Bert Text Layer 6': 0.027007488587169812,
#    'Bert Text Layer 2': 0.02068579470198641,
#    'Bert Text Layer 3': 0.031669972025666696,
#    'Bert Text Layer 7': 0.029676017662070474,
#    'GPT Text Layer 10': 0.044029956366777395,
#    'GPT Text Layer 8': 0.041114908134566634,
#    'GPT Text Layer 11': 0.04641964249087745,
#    'GPT Text Layer 9': 0.04416416342230045,
#    'GPT Text Layer 6': 0.03713019167173017,
#    'GPT Text Layer 2': 0.03125977522909622,
#    'GPT Text Layer 3': 0.04664448755624272,
#    'GPT Text Layer 7': 0.03818429408547682,
#    'GPT Text Layer 4': 0.01657864706861911,
#    'GPT Text Layer 5': 0.036167375387810466,
#    'GPT Text Layer 1': 0.018414803444313527,
#    'GPT Text Layer 12': 0.04912534585113049}}}

# %%
d_total = {}
for k1, v1 in all_filtered.items():
    d_inner = {}
    for k2, v2 in all_filtered[k1].items():
        d_res = {}
        d_res['Albef Text'] = []
        d_res['Albef Multi'] = []
        d_res['Gpt'] = []
        d_res['Vilt'] = []
        d_res['Clip'] = []
        d_res['Bert'] = []
        for k, v in all_filtered[k1][k2].items():
            if "VILT" in k:
                d_res['Vilt'].append((k,v))
            elif "Bert" in k:
                d_res['Bert'].append((k,v))
            elif "GPT" in k:
                d_res['Gpt'].append((k,v))
            elif "CLIP" in k:
                d_res['Clip'].append((k,v))
            elif "ALBEF Text" in k:
                d_res['Albef Text'].append((k,v))
            elif "ALBEF Multi" in k:
                d_res['Albef Multi'].append((k,v))
            else:
                continue
        d_inner[k2] = d_res
    d_total[k1] = d_inner

# %%
# What Im doing here is selecting for every ROI (e.g. FFA-1_lh) 
# the best layer with the highest correlation for every model
for broad_roi in d_total.keys():
    for spec_roi in d_total[broad_roi].keys():
        for model in d_total[broad_roi][spec_roi].keys():
            all_vals = d_total[broad_roi][spec_roi][model]
            tuple_with_highest_value = max(all_vals, key=lambda x: x[1])
            d_total[broad_roi][spec_roi][model] = tuple_with_highest_value

# %%
# Now I am combining all the best models for each ROI up to it's broader ROI level (eg FFA-1_lh -> Faces)
for broad_roi in d_total.keys():
    d_res = {}
    d_res['Albef Text'] = []
    d_res['Albef Multi'] = []
    d_res['Gpt'] = []
    d_res['Vilt'] = []
    d_res['Clip'] = []
    d_res['Bert'] = []
    for spec_roi in d_total[broad_roi].keys():
        for model in d_total[broad_roi][spec_roi].keys():
            if "Vilt" in model:
                d_res['Vilt'].append(d_total[broad_roi][spec_roi][model])
            elif "Gpt" in model:
                d_res['Gpt'].append(d_total[broad_roi][spec_roi][model])
            elif "Bert" in model:
                d_res['Bert'].append(d_total[broad_roi][spec_roi][model])
            elif "Clip" in model:
                d_res['Clip'].append(d_total[broad_roi][spec_roi][model])
            elif "Albef Text" in model:
                d_res['Albef Text'].append(d_total[broad_roi][spec_roi][model])
            elif "Albef Multi" in model:
                d_res['Albef Multi'].append(d_total[broad_roi][spec_roi][model])
    d_total[broad_roi] = d_res

# %%
d_total
# Out:
# {'ESC': {'Albef Text': [('ALBEF Text Layer 6', 0.07779340427872727)],
#   'Albef Multi': [('ALBEF Multi Layer 5', 0.06968936032508571)],
#   'Gpt': [('GPT Text Layer 1', 0.04137530630328651)],
#   'Vilt': [('VILT Layer 2', 0.10703017123425258)],
#   'Clip': [('CLIP Text Layer 12', 0.09491690997715377)],
#   'Bert': [('Bert Text Layer 7', 0.057407710298538)]},
#  'RSC': {'Albef Text': [('ALBEF Text Layer 3', 0.11704741563602626)],
#   'Albef Multi': [('ALBEF Multi Layer 5', 0.12750902408290732)],
#   'Gpt': [('GPT Text Layer 12', 0.026601473699243393)],
#   'Vilt': [('VILT Layer 2', 0.12977321166840503)],
#   'Clip': [('CLIP Text Layer 11', 0.14439979296429806)],
#   'Bert': [('Bert Text Layer 6', 0.09495388492239105)]},
#  'PPA': {'Albef Text': [('ALBEF Text Layer 3', 0.1122910168950697)],
#   'Albef Multi': [('ALBEF Multi Layer 5', 0.10774053367046299)],
#   'Gpt': [('GPT Text Layer 6', 0.036853637427702035)],
#   'Vilt': [('VILT Layer 2', 0.1180560550965917)],
#   'Clip': [('CLIP Text Layer 11', 0.14693224789006692)],
#   'Bert': [('Bert Text Layer 6', 0.07421077905528684)]},
#  'OPA': {'Albef Text': [('ALBEF Text Layer 3', 0.07724056604647302)],
#   'Albef Multi': [('ALBEF Multi Layer 5', 0.08588432389088141)],
#   'Gpt': [('GPT Text Layer 6', 0.031172272680497565)],
#   'Vilt': [('VILT Layer 2', 0.11299644486959987)],
#   'Clip': [('CLIP Text Layer 7', 0.11201537150084052)],
#   'Bert': [('Bert Text Layer 4', 0.058106163838741356)]},
#  'PFS': {'Albef Text': [('ALBEF Text Layer 6', 0.12139645667759096)],
#   'Albef Multi': [('ALBEF Multi Layer 5', 0.1377993640895091)],
#   'Gpt': [('GPT Text Layer 12', 0.08487828573061397)],
#   'Vilt': [('VILT Layer 10', 0.1370687130633572)],
#   'Clip': [('CLIP Text Layer 11', 0.14219926931933746)],
#   'Bert': [('Bert Text Layer 3', 0.10562991735679891)]},
#  'LOC': {'Albef Text': [('ALBEF Text Layer 6', 0.07580631215449045)],
#   'Albef Multi': [('ALBEF Multi Layer 5', 0.08240648770856679)],
#   'Gpt': [('GPT Text Layer 12', 0.04912534585113049)],
#   'Vilt': [('VILT Layer 12', 0.07693149643075527)],
#   'Clip': [('CLIP Text Layer 4', 0.09006287233095096)],
#   'Bert': [('Bert Text Layer 11', 0.03297591121480185)]}}

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_scatter_with_color_and_legend(data_sets):
    data_sets_names = list(data_sets.keys())
    labels = list(data_sets[data_sets_names[0]].keys())
    num_data_sets = len(data_sets)

    # Increase the figure size for larger individual scatter plots
    fig, ax = plt.subplots(figsize=(24, 12))

    # Color codes for the regions (you can change these to your desired colors)
    colors = {'Albef Text':'lightblue', 'Albef Multi': 'blue', 'Clip':'lightgreen', 
              'Vilt':'green', 'Bert': 'orange', 'Gpt': 'red'}

    # Create the scatterplot for each data set
    all_scatters = []
    i = 0
    z = 0
    for k, data_set in data_sets.items():
        l_x = []
        l_y = []
        l_label = []
        l_model = []
        df = pd.DataFrame(columns=['x', 'y', 'label', 'model_name'])
        values = [data_set[label] for label in labels]
        j = 1 + z
        for model_name in data_set.keys():
            old = data_set[model_name]
            y = [item[1] for item in old]
            x = [j for i in range(len(y))]

            #j += 1
            lab = [item[0] for item in old]
            model_n = [model_name for i in range(len(y))]
            l_x += x
            l_y += y
            l_label += lab
            l_model += model_n
        df['x'] = l_x
        df['y'] = l_y
        df['label'] = l_label
        df['model_name'] = l_model
        scatter = sns.scatterplot(x='x', y='y', data=df, hue='model_name', palette=colors, s=100, ax=ax, legend=False)
        
        for index, row in df.iterrows():
            ax.annotate(' '.join(row['label'].split(' ')[-2:]), (row['x'] + 0.2, row['y']), fontsize=15, ha='left', va='center')
        all_scatters.append(scatter)
        z += 4
        i += 1

    # Add labels to the x-axis
    ax.set_xticks([1.5, 5.7, 9.6, 13.6, 17.6, 21.7, 23])
    ax.set_xticklabels(data_sets_names + [''], fontsize=20)
    ax.set_ylabel('Similarity', fontsize=20)
    ax.set_xlabel('', fontsize=20)

    # Create a legend for the colors and data sets
    markers = [plt.Line2D([0,0],[0,0],color=color, marker='o', linestyle='') for color in colors.values()]
    legend = plt.legend(markers, colors.keys(), numpoints=1)
    legend.get_frame().set_alpha(0.5)    # Set the opacity of the legend box (optional)
    for text in legend.get_texts():
        text.set_fontsize(20) 
    plt.title('Multimodal vs Unimodal text transformer blocks')
    plt.show()
    
plot_scatter_with_color_and_legend(d_total)

# %%
sns.set_style('white')
sns.set(font_scale=2)

# %%
sns.set_style('white')

# %%
import pickle
file_path = 'BestTextLayers.pkl'

# Save the dictionary to the file using Pickle
with open(file_path, 'wb') as file:
    pickle.dump(d_total, file)
